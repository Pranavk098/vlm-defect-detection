# %%
# !git clone https://github.com/haotian-liu/LLaVA.git
# Out:
# Cloning into 'LLaVA'...
# remote: Enumerating objects: 2297, done.
# remote: Total 2297 (delta 0), reused 0 (delta 0), pack-reused 2297 (from 1)
# Receiving objects: 100% (2297/2297), 13.71 MiB | 14.81 MiB/s, done.
# Resolving deltas: 100% (1404/1404), done.

# %%
# %cd LLaVA
# !pip install torch==2.2.0
# !pip install -e . --no-deps
# !pip install -e ".[train]" --no-deps
# Out:
# /content/LLaVA
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.4/755.4 MB 1.8 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.6 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 119.1 MB/s eta 0:00:0000:01:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 91.8 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 60.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.7 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 20.1 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 40.7 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 14.1 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 4.8 MB/s eta 0:00:00:00:0100:01
# ...

# %%
# !nvidia-smi
# Out:
# Sun Jan 18 01:52:43 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0             49W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# ...

# %%
import os
from pathlib import Path

# Check if the directory exists in multiple possible locations
possible_paths = [
    Path("mvtec_anomaly_detection"),
    Path("/content/mvtec_anomaly_detection"),
    Path("../mvtec_anomaly_detection"),
]

data_root = None
for path in possible_paths:
    if path.exists():
        data_root = path
        print(f"Found dataset at: {data_root.absolute()}")
        break

if data_root:
    categories = sorted([d.name for d in data_root.iterdir() if d.is_dir()])
    print(f"Found {len(categories)} categories: {categories}")
else:
    print("Warning: MVTec Anomaly Detection dataset not found in expected locations")
    print("Expected at: c:\\Users\\prana\\Desktop\\VLM\\mvtec_anomaly_detection")
    print("Download from: https://www.mvtec.com/company/research/datasets/mvtec-ad")
    categories = []
# Out:
# ...
# Expected at: c:\Users\prana\Desktop\VLM\mvtec_anomaly_detection
# Download from: https://www.mvtec.com/company/research/datasets/mvtec-ad
